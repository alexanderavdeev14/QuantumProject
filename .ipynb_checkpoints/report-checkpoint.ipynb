# %% [markdown]
# ## Introduction
# In this project we will look at the different sources of the decoherence of the qubit spin 1/2. The sources that we will look at are: pure dephasing, pure decay and thermal decoherence. Additionally we will also look at the similarity between two collapse operators $\sigma_x$, and $\sigma_-$ and $\sigma_+$ in context of the thermal bath.

# %% [markdown]
# ##  Description of the physical problem we want to simulate
#
#
# The pure dephasing happens when the qubit spin 1/2 is placed in a magnetic field that fluctuates in time and we assume that there is no other interaction with the system. The fluctuations lead to the fluctuations in Larmor frequency $\omega_l = g\mu_bB_o$ of the spin 1/2. If we look at the frequency domain we will observe Laurensian shape of the frequency around wl. This variance in the frequency denotes the uncertainty as time goes on it becomes harder to know what frequency of the 1/2 spin qubit is. "Classically" you can imagine this as a pendulum with a dampening that changes in time. Since we aren't measuring it, you can also imagine a box covering the pendulum. Since the dampening factor changes in time it becomes very difficult to know what the current frequency is. Offcource eventually it becomes zero due to dampening over time, however, this can be ignored for this example. As it is known from 1/2 spin qubits there exist pure, mixed en completely mixed. The meaning behind this as you go from pure towards mixed you know less about the 1/2 spin qubits and when you reach completely mixed you know nothing more about the 1/2 spin qubit. Decoherence means that the off-diagonal of a state are 0. Mixed states have the characteristic of having off diagonals of zero. So just like the "classical" example for a pendulum the phase of the 1/2 spin qubit becomes less certain over time due to the fluctuating magnetic field. As a result the off diagonal elements of the spins density matrix heads towards zero.
#
# $$
# \textbf{$\rho$} =
# \begin{pmatrix}
# \rho_{11}\ \rho_{12}\\
# \rho_{21}\ \rho_{22}
# \end{pmatrix}
# $$
#
# The pure decaying happens when the spin 1/2 decays with some decay rate from the excited state to ground state. In this case we have a non fluctuating magnetic field. However, in this case we are going to measure the 1/2 spin qubit. We will want to know if it is a spin up or spin down. The question arises, how it is lead to defacing?. You can measure the spin up or spin down of a photon in a magnetic field. Due to the fact that you are measuring it you will collapse it. The collapse operator depends on if you are measuring spin up or spin down. If the initial state is spinning up, due to collapse operator the average over time will be spin down. Before measurement the 1/2 spin had a fixed frequency, due to the fact that the magnetic field is not fluctuating. Measurement adds a form of exponential decay, the decay explains how the diagonals change over time. Therefor the total representation of the wave function is $\phi=e^{-a}*cos(b)$. The a and b are arbitrary. The exponential does not change the phase only the magnitude. However, if the Fourier transform is preformed on $\phi$ the result is a pulse. This means that the frequency of the 1/2 spin qubit in the perfect magnetic field changes due to measurement. As the case with the fluctuating magnetic field as you keep measuring the spin the state will eventually be pure mixed. It is also important to note that for pure decay the condition $T_2 = 2T_1$ have to be met, where T1 and T2 are respectively decay period of the diagonal and off-diagonal elements of the density matrix shown below.
#
# $$
# \textbf{$\rho$} =
# \begin{pmatrix}
# \rho_{11}e^{-1/T_1}\ \rho_{12}e^{-1/T_2}\\
# \rho_{21}e^{-1/T_2}\ \rho_{22}e^{-1/T_1}
# \end{pmatrix}
# $$
#
# The last source of decoherence we are going to look at is environmental i.e 'thermal bath'. The 1/2 spin qubit in the environment can give energy to it, but it can also absorb energy from it. If the temperature is zero. The 1/2 spin qubit can only take energy and if the temperature approaches infinity we would assume that the qubit spin 1/2 would only receive energy. However the Boltzmann statistics suggest that is not the case. When working with the environment you have to use Boltzmann statistic as a tool to figure the thermal occupation number or in short $n_ {th} $. As taking energy can be seen as being in the excited state and giving energy can be seen as being in the ground state. Even at extremelly hot temperature as you try to measure if the 1/2 spin qubit is either giving or receiving energy you are once again effecting it. After a few measurements the spin will be in a completely mixed state. What's interesting about this is the rate in which the spin becomes decoherent.
#
# $$
# n_{th} = \frac{1}{1-e^{\hbar/k_bT}}
# $$
#
# As we will see from the simulation the thermal environment can be modulated with the help of $\sigma_-$ and $\sigma_+$. Since $\sigma_x$ is the addition of $\sigma_-$ and $\sigma_+$ the question arises: if we use $\sigma_x$ as our collapse operator will it results in the same depressing as the $\sigma_-$ and $\sigma_+$ collapse operators? I.e. will it simulate thermal decoherence for all states?

# %% [markdown]
# ## Aim and scope of this project
# With this project we are trying to understand how different sources of decoherence affect qubit spin 1/2 by finding the answer to following questions:
# 1. How to simulate pure depressing that is the result of the fluctuations of the magnetic field?
# 2. What is a good model of pure decay?
# 3. How to simulate thermal decoherence?
# 4. Is $\sigma_x$ the same as collapse operators $\sigma_-$ and $\sigma_+$ in context of the thermal bath of qubit spin 1/2?

# %% [markdown]
# ## Techniques and approach
#
# The first model of the qubit spin 1/2 will be created with the help of `basis()` function. The created superposition will be normalized with `unit()`. This sate is used for all simulations. The evolution of the state is then determined by the Linblad equation `mesolve ()`, where we use collapse operators to simulate physical environment. The Hamiltonian of our system is $ H =\frac{\omega_l\sigma_z}{2} $
#
# ### Simualting pure dephasing
# To simulate pure dephasing we need a collapse operator that has the eigenstate corresponding to our qubit spin 1/2. We know that fortunately als a Pauli matrices $\sigma_z$. The total collapse operator is
#
# $$
# C_ {dephasing} = \sqrt{\gamma}\sigma_z
# $$
#
# where $\gamma$ is the collapse rate. Since we are modeling the fluctuations in frequency $\Delta\omega$ we can replace $\gamma$ by $\Delta\omega$. The decoherence should decay as $e^{-\Delta\omega t} $.

# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms

N = 2                                    # Length of Hilbert Space
tmin = 0                                 # Start time of the simulation
tmax = 10                                # End time of the simulation
psi2= basis(N,0)+basis(N,1)              # Spin (/0>+/1>)
psi2= psi2.unit()                        # Spin (/0>+/1>)/sqrt(2)
delta_w = 0.1                            # Uncertainty
w_l = 1                                  #Larmor frequency
C_ops = []                               # colaps operator list
times = np.linspace(tmin,tmax,400)       #time of the simulation
C_ops = [np.sqrt(delta_w)*sigmaz()]      #Collaps operator
H = 0.5 * w_l * sigmaz()                 #Hamiltionion
result = mesolve(H, psi2, times, C_ops)  # Linkblad Equation

# %% [markdown]
# ### Simulating pure decoherence
#
# To simulate pure decoherence we use collapse operator
# $$
# C_{decay} = \sqrt{\gamma}\sigma_-
# $$
# where $\gamma = \frac{1}{T_{decay}}$. $T_{decay}$ is the rate at which the qubit spin 1/2 decay from higher energy to lower energy. If we solve the linblad equation manually, we observe that the off-diagonal elements of $\rho$ should decay as $e^{-\frac{\gamma t}{2}}$

# %%
gamma = 0.4                              #Gamma
w_l = 1                                  #Larmor frequency
C_ops = [np.sqrt(gamma)*sigmam()]        #Collaps operator
H = 0.5 * w_l * sigmaz()                 #Hamiltionion
result = mesolve(H, psi2, times, C_ops)   # Linblad Equation

# %% [markdown]
# ### Thermal decoherence
# Since the qubit spin 1/2 gains and loses energy we will use the following collapse operators $\alpha_-\sigma_-$ and $\alpha_+\sigma_+$. The  $\alpha_+$ and  $\alpha_-$ is some function of  $n_{th}$. If T is zero, then only the environment gains energy from spin 1/2. The $n_{th}$ is zero at that T = 0. This means that  $\alpha_+ = \sqrt{\gamma n_{th}}$ and $\alpha_- = \sqrt{\gamma (n_{th}+1)}$. The dephasing rate is $2(\gamma (n_{th}+1) + \gamma (n_{th}))$

# %%
kb=1.38e-23                           #Boltman's constant
T=1000                                #Temperature
wl = 1                                #Larmor frequency
nther=1/(1-np.exp(wl/kb*T))           #Thermal occupation number 
H = 0.5 * wl * sigmaz()               #Hamiltionion
gamma = 0.1                           #Gamma
gamma_plus = gamma*(nther)          #Gamma for plus operator
gamma_minus = gamma*(nther+1)             #Gamma for minus operator
C_ops = [np.sqrt(gamma_plus)*sigmap(),np.sqrt(gamma_minus)*sigmam()]

# %% [markdown]
# ### Thermal decoherence with $\sigma_x$
# Since the thermal collapse operator is represented with $\sqrt{\gamma n_{th}}*\sigma_+ +\sqrt{\gamma (n_{th}+1)} *\sigma_-$. $\hspace{2mm}$  $\sigma_x=\sqrt\gamma*\sigma_x$, Where the first $\sigma_x$ is the collapse operator.

# %% [markdown]
# ## Results
# For all simulations we used $\omega_l = 1$. We are also working with the normalized state of the qubit spin 1/2. Though we tried different state, the state below gives the most interesting results.
# $$
# \Psi = \frac{1}{\sqrt{2}}( \left| 0\right\rangle + \left| 1\right\rangle )
# $$
#
# ### Pure dephasing
# The plot below shows the evolution of the off-diagonal elements of the $\rho$ matrix and the exponential  decay function $e^{-\Delta\omega t}$ with the collapse operator $C_{dephasing}$ where $\Delta\omega = 0.05 $. The plots show indeed that the fluctuations  of the off diagonal elements dephase and the dephasing follow the exponential $e^{-\Delta\omega t}$.
# <img src="Plots/pure_dephasing_offdia.png" width=60%>
#
# ### Pure decay
# From the plot that is represented below, we can conclude that the pure decay indeed leads to the dephasing of the system and it is only valid when $2T_2 = T_1 $. The green and the blue lines in the plot of the diagonal elements are actually on top of each other
# <img src="Plots/pure_decaying.png" width=70%>
#
# ### Thermal decoherence
# By simulating the qubit 1/2 in a hot environment at $T_{emp} = 1000 K$, we found that decoherence rate is $2(\gamma n_{th}/2 + \gamma (1+n{th}) + constant)$ and in our example it is approximately 0.1. Where constant is equal to 0.024 in our example and it is found by iterating process and chosen to be the constant that gives the best fit between  decaying density  matrix elements and the decaying exponential as we show in the plot below.
# <img src="Plots/thermal_bath.png" width=70%>
#
# ### $\sigma_x$ operator and the thermal bath
# By comparing plots in 5.3 and the plot below, the we can see that there is a difference between collapse operator $\sigma_x$, and $\sigma_-$ and $\sigma_+$. The decoherence time is two times larger and the populations do not change. The decoherence rate is $\gamma$ and it is equal to 0.1 in our example as in the 5.3.  This is an interesting  result by itself, since it shows that the sum of two collapse operators does not necessarily results in the collapse operator that corresponds to that sum. $\sigma_x$ is similar  to $\sigma_z$ operator, since it results in pure dephasing because there is no decay of populations and  $2T_2 \neq T_1$.
#
# <img src="Plots/sigma_x.png" width=70%>

# %% [markdown]
# ## Summary and Outlook

# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Creating the qubit spin 1/2 state and defining meaningful variables for the simulations.

# %% [markdown]
# ### General parameters

# %%
N = 2                               # Length of Hilbert Space
tmin = 0                            # Start time of the simulation
tmax = 10                           # End time of the simulation
psi0 = basis(N, 0)                  # Spin up
psi1 = basis(N, 1)                  # Spin down
psi2 = psi0 + psi1
psi2 = psi2.unit()                  # Normalization of psi0 + pis1 to get the superposition of |0>+|1> 
psiI = 1j*psi0+psi1
psiI = psiI.unit()                  # Normalization  i*|0>+|1> 
delta_w = 0.0                       # Uncertainty
w_l = 0.0                           # Larmor frequency
C_ops = []                          # Colaps operator list
times = np.linspace(tmin,tmax,400)  # Time of the simulation

# %% [markdown]
# Now solving linblad equation for the pure dephasing and plotting the off diagonal matrix and the exponential $e^{-\Delta\omega t}$

# %% [markdown]
# ### Pure dephasing

# %%
delta_w = 0.1
w_l = 1
C_ops = [np.sqrt(delta_w)*sigmaz()]
H = 0.5 * w_l * sigmaz()
result = mesolve(H, psi2, times, C_ops)


figure_size =  [13,13]
plt.figure(figsize = figure_size)

plt.subplot(311)
plt.title(r'The evolution of the $\rho_{11}$ and $\rho_{22}$ element of density matrix for pure dephasing' \
           ,weight="bold")
plt.ylim(0, 1)
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,0,0))), label=r'$Re(\rho_{11})$');
plt.plot(times,np.real(expect(result.states, projection(2,1,1))), label=r'$Re(\rho_{22})$');
plt.legend()
plt.ylabel(r"$\rho_{ii}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(312)
plt.title(r'The evolution of the $\rho_{12}$ element of density matrix for pure dephasing',weight="bold")
plt.ylim(-0.5, 0.5)
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,1,0))), label=r'Re');
plt.plot(times,np.imag(expect(result.states, projection(2,1,0))), label=r'Im');
plt.plot(times,0.5*np.exp(-2*delta_w*times), label=r'exponential decay');
plt.legend(loc = 4)
plt.ylabel(r"$\rho_{12}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(313)
plt.title(r'The evolution of the $\rho_{21}$ element of density matrix for pure dephasing',weight="bold")
plt.ylim(-0.5, 0.5)
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,0,1))), label=r'Re');
plt.plot(times,np.imag(expect(result.states, projection(2,0,1))), label=r'Im');
plt.plot(times,0.5*np.exp(-2*delta_w*times), label=r'exponential decay');
plt.legend(loc = 4)
plt.ylabel(r"$\rho_{21}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

# %% [markdown]
# Defining a collapse operator for pure decay, solving Lindblad equation and plotting the elements of the resulting evolution of the density matrix. Also the decaying exponential is plotted for $T_1$ and $T_2$.

# %% [markdown]
# ### Pure Dephasing

# %%
gamma = 0.4
w_l = 1
C_ops = [np.sqrt(gamma)*sigmam()]
H = 0.5 * w_l * sigmaz()
result = mesolve(H, psi2, times, C_ops)
exp_decay_off_diag = 0.5*np.exp(-gamma/2*times)
exp_decay_diag = 0.5*np.exp(-gamma*times)


figure_size =  [13,13]
plt.figure(figsize = figure_size)

plt.subplot(311)
plt.title(r'The evolution of the $\rho_{11}$ and $\rho_{22}$ element of density matrix for pure decaying' \
           ,weight="bold")
plt.ylim(0, 1)
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,0,0))), label=r'$Re(\rho_{11})$');
plt.plot(times,np.real(expect(result.states, projection(2,1,1))), label=r'$Re(\rho_{22})$');
plt.plot(times,exp_decay_diag, label=r'Exponential decay with $\gamma$ = $1/T_1$');
plt.legend()
plt.ylabel(r"$\rho_{ii}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(312)
plt.title(r'The evolution of the $\rho_{12}$ element of density matrix for pure decaying',weight="bold")
plt.ylim(-0.5, 0.5)
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,1,0))), label='Re');
plt.plot(times,np.imag(expect(result.states, projection(2,1,0))), label='Im' );
plt.plot(times,exp_decay_off_diag, label=r'Exponential decay with $\gamma$ = $1/T_2$');
plt.legend(loc = 4)
plt.ylabel(r"$\rho_{12}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(313)
plt.title(r'The evolution of the $\rho_{21}$ element of density matrix for pure decaying',weight="bold")
plt.ylim(-0.5, 0.5)
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,0,1))), label='Re');
plt.plot(times,np.imag(expect(result.states, projection(2,0,1))), label='Im');
plt.plot(times,exp_decay_off_diag, label=r'Exponential decay with $\gamma$ = $1/T_2$');
plt.legend(loc = 4)
plt.ylabel(r"$\rho_{21}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

# %% [markdown]
# For the thermal decoherence we have two collapse operators. And the rate at which the off diagonal elements decay is $2(\gamma n_{th}/2 + \gamma (1+n{th}) + const)$. This constant is determined by experimental try different constants and see which value results in a better fit between the decaying complex exponential and the exponential decay

# %% [markdown]
# ### Thermal bath

# %%
kb=1.38e-23
T=1000
wl = 1 
nther=1/(1-np.exp(wl/kb*T)) 
H = 0.5 * wl * sigmaz()
gamma = 0.1
gamma_plus = gamma*(nther)
gamma_minus = gamma*(1+nther) 
C_ops = [np.sqrt(gamma_minus) * sigmam(),np.sqrt(gamma) * sigmaz(),np.sqrt(gamma_plus) * sigmap()]
result = mesolve(H,psi2 , times, C_ops)




figure_size =  [13,13]
plt.figure(figsize = figure_size)

plt.subplot(311)
plt.title(r'The evolution of the $\rho_{11}$ and $\rho_{22}$ element of density matrix for qubit in thermal enviroment' \
           ,weight="bold")
plt.xlim(tmin, tmax)
plt.ylim(0, 1.1)
plt.plot(times,np.real(expect(result.states, projection(2,0,0))), label=r'$\rho_{11}$');
plt.plot(times,np.real(expect(result.states, projection(2,1,1))),          label=r'$\rho_{22}$');
plt.legend()
plt.ylabel(r"$\rho_{ii}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(312)
plt.title(r'The evolution of the $\rho_{12}$ element of density matrix for qubit in thermal enviroment',weight="bold")
plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,0,1))), label=r'Re');
plt.plot(times,np.imag(expect(result.states, projection(2,0,1))), label=r'Im');
plt.plot(times,0.5*np.exp(-2*(gamma_plus+gamma_minus+0.024)*times), label=r'Exponential decay');
plt.legend() 
plt.ylabel(r"$\rho_{12}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(313)
plt.title(r'The evolution of the $\rho_{21}$ element of density matrix for qubit in thermal enviroment',weight="bold")
plt.xlim(tmin, tmax)
plt.ylim(-0.5, 0.5)
plt.plot(times,np.real(expect(result.states, projection(2,1,0))), label=r'Re');
plt.plot(times,np.imag(expect(result.states, projection(2,1,0))), label=r'Im');
plt.plot(times,0.5*np.exp(-2*(gamma_plus+gamma_minus+0.024)*times), label=r'Exponential decay');
plt.legend() 
plt.ylabel(r"$\rho_{21}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

# %% [markdown]
# Now we are going to simulate "thermal bath" with collapse operator $\sigma_x$. To compare  $\sigma_x$ with  $\sigma_-$ and $\sigma_+$, we will use the same $\gamma = 0.1$ as for thermal dicoherence simulate described above.

# %% [markdown]
# ### $\sigma_x$ as thermal operator

# %%
kb=1.38e-23
T=1000
wl = 1 
nther=1/(1-np.exp(wl/kb*T)) 
H = 0.5 * wl * sigmaz()
gamma = 0.1
C_ops = [np.sqrt(gamma)*sigmax()]
result = mesolve(H,psi2 , times, C_ops)



figure_size =  [13,13]
plt.figure(figsize = figure_size)


plt.subplot(311)
plt.title(r'''The evolution of the $\rho_{11}$ and $\rho_{22}$ element of density matrix for qubit in thermal enviroment
            with $\sigma_x$ collapse operator''',weight="bold")
plt.xlim(tmin, tmax)
plt.ylim(0, 1.1)
plt.plot(times,np.real(expect(result.states, projection(2,0,0))), label=r'$\rho_{11}$');
plt.plot(times,np.real(expect(result.states, projection(2,1,1))),          label=r'$\rho_{22}$');
plt.legend()
plt.ylabel(r"$\rho_{ii}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(312)
plt.title(r'''The evolution of the $\rho_{12}$ element of density matrix for qubit in thermal enviroment with 
             $\sigma_x$ collapse operator''',weight="bold")

plt.xlim(tmin, tmax)
plt.plot(times,np.real(expect(result.states, projection(2,0,1))), label=r'Re');
plt.plot(times,np.imag(expect(result.states, projection(2,0,1))), label=r'Im');
plt.plot(times,0.5*np.exp(-(gamma)*times), label=r'Exponential decay');
plt.legend() 
plt.ylim(-0.5, 0.5)
plt.ylabel(r"$\rho_{12}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()

plt.subplot(313)
plt.title(r'''The evolution of the $\rho_{2}$ element of density matrix for qubit in thermal enviroment 
            with $\sigma_x$ collapse operator''',weight="bold")
plt.xlim(tmin, tmax)
plt.ylim(-0.5, 0.5)
plt.plot(times,np.real(expect(result.states, projection(2,1,0))), label=r'Re');
plt.plot(times,np.imag(expect(result.states, projection(2,1,0))), label=r'Im');
plt.plot(times,0.5*np.exp(-(gamma)*times), label=r'Exponential decay');
plt.legend() 
plt.ylabel(r"$\rho_{12}$")
plt.xlabel("t (QuTiP 'seconds')")
plt.tight_layout()
